# %% [markdown]
# ###  HTTP
#
# 소켓 모듈을 통한 네트워크 연결
#
# HTTP를 이용해 서버에 요청 보내기
#
# 파이썬을 이용해 웹 데이터 읽어오기
#
# <실습> 소켓
#
# 문자를 표현하는 방법 및 인코딩과 디코딩
#
# urllib를 이용해 웹 데이터 읽어오기
#
# <실습> Urllib
#
# BeautifulSoup를 이용한 웹 데이터 스크래핑
#
# <실습> BeautifulSoup

# %%
import socket

mysock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
mysock.connect(('data.pr4e.org', 80))
cmd = 'GET http://data.pr4e.org/romeo.txt HTTP/1.0\r\n\r\n'.encode()
mysock.send(cmd)

while True:
    data = mysock.recv(512)
    if (len(data) < 1):
        break
    print(data.decode(),end='')
mysock.close()
# Out:
# HTTP/1.1 200 OK
# Date: Sat, 07 Mar 2020 04:54:25 GMT
# Server: Apache/2.4.18 (Ubuntu)
# Last-Modified: Sat, 13 May 2017 11:22:22 GMT
# ETag: "a7-54f6609245537"
# Accept-Ranges: bytes
# Content-Length: 167
# Cache-Control: max-age=0, no-cache, no-store, must-revalidate
# Pragma: no-cache
# Expires: Wed, 11 Jan 1984 05:00:00 GMT
# Connection: close
# Content-Type: text/plain
#
# But soft what light through yonder window breaks
# It is the east and Juliet is the sun
# Arise fair sun and kill the envious moon
# Who is already sick and pale with grief

# %%
import urllib.request, urllib.parse, urllib.error

fhand = urllib.request.urlopen('http://data.pr4e.org/romeo.txt')
for line in fhand:
    print(line.decode().strip())
# Out:
# But soft what light through yonder window breaks
# It is the east and Juliet is the sun
# Arise fair sun and kill the envious moon
# Who is already sick and pale with grief

# %%
import urllib.request, urllib.parse, urllib.error

fhand = urllib.request.urlopen('http://data.pr4e.org/romeo.txt')

counts = dict()
for line in fhand:
    words = line.decode().split()
    for word in words:
        counts[word] = counts.get(word, 0) + 1
print(counts)
# Out:
# {'But': 1, 'soft': 1, 'what': 1, 'light': 1, 'through': 1, 'yonder': 1, 'window': 1, 'breaks': 1, 'It': 1, 'is': 3, 'the': 3, 'east': 1, 'and': 3, 'Juliet': 1, 'sun': 2, 'Arise': 1, 'fair': 1, 'kill': 1, 'envious': 1, 'moon': 1, 'Who': 1, 'already': 1, 'sick': 1, 'pale': 1, 'with': 1, 'grief': 1}

# %%
import urllib.request, urllib.parse, urllib.error

fhand = urllib.request.urlopen('http://www.dr-chuck.com/page1.htm')
for line in fhand:
    print(line.decode().strip())
# Out:
# <h1>The First Page</h1>
# <p>
# If you like, you can switch to the
# <a href="http://www.dr-chuck.com/page2.htm">
# Second Page</a>.
# </p>

# %%
import urllib.request, urllib.parse, urllib.error
from bs4 import BeautifulSoup

url = input('Enter - ')
html = urllib.request.urlopen(url).read()
soup = BeautifulSoup(html, 'html.parser')

# Retrieve all of the anchor tags
tags = soup('a')
for tag in tags:
    print(tag.get('href', None))
# Out:
# Enter - http://www.dr-chuck.com/page1.htm
# http://www.dr-chuck.com/page2.htm

# %%
import urllib.request, urllib.parse, urllib.error
from bs4 import BeautifulSoup

url = input('Enter - ')
html = urllib.request.urlopen(url).read()
soup = BeautifulSoup(html, 'html.parser')

# Retrieve all of the anchor tags
tags = soup('a')
for tag in tags:
    print(tag.get('href', None))
# Out:
# Enter - https://www.naver.com/
# #news_cast
# #themecast
# #time_square
# #shp_cst
# #account
# https://whale.naver.com/ko?=main
# http://update.whale.naver.net/downloads/installers/WhaleSetup.exe
# /
# http://help.naver.com/support/alias/contents2/naverhome/naverhome_1.naver
# http://jr.naver.com
# http://happybean.naver.com/main/SectionMain.nhn
# javascript:;
# javascript:;
# https://help.naver.com/support/contents/contents.nhn?serviceNo=606&categoryNo=16658
# #
# #
# https://nid.naver.com/nidlogin.login
# https://help.naver.com/support/alias/search/word/word_16.naver
# https://help.naver.com/support/contents/contents.nhn?serviceNo=606&categoryNo=16659
# https://help.naver.com/support/service/main.nhn?serviceNo=606&categoryNo=1987
# https://help.naver.com/support/contents/contents.nhn?serviceNo=605&categoryNo=18215
# javascript:;
# javascript:;
# https://help.naver.com/support/service/main.nhn?serviceNo=606&categoryNo=1987
# https://help.naver.com/support/contents/contents.nhn?serviceNo=605&categoryNo=18215
# javascript:;
# javascript:;
# https://help.naver.com/support/service/main.nhn?serviceNo=606&categoryNo=1987
# https://help.naver.com/support/contents/contents.nhn?serviceNo=605&categoryNo=18215
# javascript:;
# javascript:;
# https://help.naver.com/support/service/main.nhn?serviceNo=606&categoryNo=1987
# https://help.naver.com/support/contents/contents.nhn?serviceNo=605&categoryNo=18215
# javascript:;
# javascript:;
# javascript:;
# javascript:;
# javascript:;
# javascript:;
# javascript:;
# javascript:;
# javascript:;
# javascript:;
# javascript:;
# javascript:;
# javascript:;
# javascript:;
# javascript:;
# javascript:;
# javascript:;
# javascript:;
#
# https://mail.naver.com/
# https://section.cafe.naver.com/
# https://section.blog.naver.com/
# https://kin.naver.com/
# https://shopping.naver.com/
# https://order.pay.naver.com/home
# https://tv.naver.com/
# https://dict.naver.com/
# https://news.naver.com/
# https://finance.naver.com/
# https://land.naver.com/
# https://map.naver.com/
# https://movie.naver.com/
# https://vibe.naver.com/?from=naver_main
# https://book.naver.com/
# https://comic.naver.com/
# #
# http://news.naver.com/main/list.nhn?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y
# http://news.naver.com/main/list.nhn?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0011455703
# http://news.naver.com/main/list.nhn?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0011455700
# http://news.naver.com/main/list.nhn?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0011455685
# http://news.naver.com/main/list.nhn?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0011455619
# http://news.naver.com/main/list.nhn?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0011455642
# http://news.naver.com/main/list.nhn?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0011455598
# http://news.naver.com/main/list.nhn?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0011455614
# http://news.naver.com/main/list.nhn?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0011455535
# http://news.naver.com/main/list.nhn?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0011455596
# http://news.naver.com/main/list.nhn?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0011455415
# http://news.naver.com/
# http://entertain.naver.com/home
# http://sports.news.naver.com/
# http://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=101
# http://newsstand.naver.com/
# #
# #
# #
# #
# http://newsstand.naver.com/config.html
# #
# #
# http://newsstand.naver.com/?list=ct1&pcode=020
# #
# #
# http://newsstand.naver.com/?list=ct1&pcode=020
# http://newsstand.naver.com/?list=ct1&pcode=029
# #
# #
# http://newsstand.naver.com/?list=ct1&pcode=029
# http://newsstand.naver.com/?list=ct1&pcode=023
# #
# #
# http://newsstand.naver.com/?list=ct1&pcode=023
# http://newsstand.naver.com/?list=ct1&pcode=030
# #
# #
# http://newsstand.naver.com/?list=ct1&pcode=030
# http://newsstand.naver.com/?list=ct1&pcode=022
# #
# #
# http://newsstand.naver.com/?list=ct1&pcode=022
# http://newsstand.naver.com/?list=ct1&pcode=109
# #
# #
# http://newsstand.naver.com/?list=ct1&pcode=109
# http://newsstand.naver.com/?list=ct1&pcode=314
# #
# #
# http://newsstand.naver.com/?list=ct1&pcode=314
# http://newsstand.naver.com/?list=ct1&pcode=277
# #
# #
# http://newsstand.naver.com/?list=ct1&pcode=277
# http://newsstand.naver.com/?list=ct1&pcode=021
# #
# #
# http://newsstand.naver.com/?list=ct1&pcode=021
# http://newsstand.naver.com/?list=ct1&pcode=930
# #
# #
# http://newsstand.naver.com/?list=ct1&pcode=930
# http://newsstand.naver.com/?list=ct1&pcode=005
# #
# #
# http://newsstand.naver.com/?list=ct1&pcode=005
# http://newsstand.naver.com/?list=ct1&pcode=214
# #
# #
# http://newsstand.naver.com/?list=ct1&pcode=214
# http://newsstand.naver.com/?list=ct7&pcode=329
# #
# #
# http://newsstand.naver.com/?list=ct7&pcode=329
# http://newsstand.naver.com/?list=ct7&pcode=908
# #
# #
# http://newsstand.naver.com/?list=ct7&pcode=908
# http://newsstand.naver.com/?list=ct7&pcode=050
# #
# #
# http://newsstand.naver.com/?list=ct7&pcode=050
# http://newsstand.naver.com/?list=ct2&pcode=823
# #
# #
# http://newsstand.naver.com/?list=ct2&pcode=823
# http://newsstand.naver.com/?list=ct8&pcode=926
# #
# #
# http://newsstand.naver.com/?list=ct8&pcode=926
# http://newsstand.naver.com/?list=ct8&pcode=338
# #
# #
# http://newsstand.naver.com/?list=ct8&pcode=338
# #
# #
# #
# #
# #
# #
# #
# http://newsstand.naver.com/config.html
# https://nid.naver.com/nidlogin.login?mode=form&url=https%3A%2F%2Fwww.naver.com
# https://nid.naver.com/nidregister.form?url=https%3A%2F%2Fwww.naver.com
# https://nid.naver.com/user/help.nhn?todo=idinquiry
# https://nid.naver.com/nidreminder.form
# https://calendar.naver.com
# #
# #
# https://search.naver.com/search.naver?sm=top_hty&fbm=1&ie=utf8&query=%EC%BD%94%EB%A1%9C%EB%82%9819
# https://tv.naver.com/ktv/playlists
# http://blog.naver.com/kfdazzang/221839489769
# https://search.naver.com/search.naver?sm=top_hty&fbm=0&ie=utf8&query=%EC%BD%94%EB%A1%9C%EB%82%9819+%EC%98%88%EB%B0%A9%EB%B2%95
# https://search.naver.com/search.naver?sm=top_sly.hst&fbm=1&acr=1&ie=utf8&query=%EA%B5%AD%EB%AF%BC%EC%95%88%EC%8B%AC%EB%B3%91%EC%9B%90
# https://search.naver.com/search.naver?sm=top_hty&fbm=1&ie=utf8&query=%EC%BD%94%EB%A1%9C%EB%82%9819
# #LIVINGHOME
# #LIVING
# #SPORTS
# #CARGAME
# #BEAUTY
# #MOMKIDS
# #HEALTH
# #BBOOM
# #GAMEAPP
# #VIDEO
# #MUSIC
# #MOVIE
# #CULTURE
# #WITH
# #TRAVEL
# #DESIGN
# #FINANCE
# #JOB
# #SCIENCE
# #CHINA
# #BUSINESS
# #FARM
# #SCHOOL
# #SHOW
# #LAW
# #ANIMAL
# #WEDDING
# #ITTECH
# #
# #
# #
# #
# #
# #
# #
# #
# #
# https://happybean.naver.com/
# https://happybean.naver.com/donation/DonateHomeMain.nhn
# https://happybean.naver.com/crowdFunding/Home
# https://happybean.naver.com/flower/product
# https://happybean.naver.com/volunteer
# https://happybean.naver.com/prddeposit/main.nhn
# https://happybean.naver.com/campaignhome/Main.nhn
# https://blog.naver.com/nv_withn
# https://happybean.naver.com/flower/brand/tenyearsafter
# https://happybean.naver.com/goodAction/1184
# https://happybean.naver.com/donations/H000000170807?p=p&s=s
# https://happylog.naver.com/kwf6693.do
# https://happybean.naver.com/crowdFunding/Intro/H000000170078
# https://happybean.naver.com/specialdouble/hyundai-steel?doubleYm=1
# https://happybean.naver.com/donations/H000000170603?p=p&s=s
# https://happylog.naver.com/hlog/hil/home
# https://happybean.naver.com/donations/H000000170496?p=p&s=s
# https://happylog.naver.com/hlog/changemaker/home
# https://happybean.naver.com/goodAction/1185
# https://blog.naver.com/riblog/221822765193
# https://happybean.naver.com/donations/H000000170456?p=p&s=s
# https://happylog.naver.com/hlog/greentraffic/home
# https://post.naver.com/viewer/postView.nhn?volumeNo=27487666&memberNo=12494964
# https://happybean.naver.com/goodAction/1181
# https://happybean.naver.com/flower/brand/lumir
# https://fund.happybean.naver.com/congfund/FundView/postscripts/123462936018?fundno=1505797
# https://castbox.shopping.naver.com/shopbox/main.nhn?
# http://api.happybean.naver.com/congbanner/content/fn5s8o.nhn
# http://naver.me/FNiR0TAU
# //www.naver.com/NOTICE
# more.html
# https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=1&ie=utf8&query=%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8%EA%BD%83
# https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=1&ie=utf8&query=%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8%EA%BD%83
# http://whale.naver.com/
# http://whale.naver.com/
# https://www.navercorp.com/service/creators
# https://www.navercorp.com/service/business
# https://business.naver.com/service.html
# https://sell.storefarm.naver.com/#/home/about
# https://smartplace.naver.com/
# https://developers.naver.com
# https://developers.naver.com/docs/common/openapiguide/#/apilist.md/
# https://naver.github.io/
# https://d2.naver.com/
# http://d2startup.com/
# https://www.naverlabs.com/
# https://www.navercorp.com/
# https://recruit.navercorp.com/naver/recruitMain
# https://www.navercorp.com/naver/proposalGuide
# /policy/service.html
# /policy/privacy.html
# /policy/youthpolicy.html
# /policy/spamcheck.html
# https://help.naver.com/
# https://www.navercorp.com/

# %%
# To run this, you can install BeautifulSoup
# https://pypi.python.org/pypi/beautifulsoup4

# Or download the file
# http://www.py4e.com/code3/bs4.zip
# and unzip it in the same directory as this file

import urllib.request, urllib.parse, urllib.error
from bs4 import BeautifulSoup
import ssl

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

url = input('Enter - ')
html = urllib.request.urlopen(url, context=ctx).read()
soup = BeautifulSoup(html, 'html.parser')

# Retrieve all of the anchor tags
tags = soup('a')
for tag in tags:
    print(tag.get('href', None))
# Out:
# Enter - https://www.daum.net/
# #mainServiceTitle
# #todayInfoTitle
# #mediaTitle
# #liveIssueTitle
# #multiMediaTitle
# #blogTitle
# #storyTitle
# #shoppingTitle
# #photoClipTitle
# /doc/top_accessibility.html
# /doc/top_accessibility.html#ad
# https://www.daum.net/
# https://search.daum.net/search?w=tot&q=%EC%BD%94%EB%A1%9C%EB%82%9819+%ED%98%84%ED%99%A9&DA=NPI
# https://search.daum.net/search?w=tot&q=%EB%8C%80%EA%B5%AC%EC%95%84%ED%8C%8C%ED%8A%B8+%EA%B2%A9%EB%A6%AC&DA=NPI&rtmaxcoll=NNS
# https://search.daum.net/search?w=tot&q=%EB%85%B8%ED%8A%B8%EB%B6%81%EB%A0%8C%ED%83%88&DA=NPT
# https://search.daum.net/search?w=tot&q=%ED%83%80%EB%8B%A4%EA%B8%88%EC%A7%80%EB%B2%95+%ED%86%B5%EA%B3%BC&DA=NPI&rtmaxcoll=NNS
# https://search.daum.net/search?w=tot&q=%ED%99%94%EB%B6%84%EB%B0%B0%EB%8B%AC%EC%84%9C%EB%B9%84%EC%8A%A4&DA=NPT
# https://search.daum.net/search?w=tot&q=%EC%BD%94%EB%A1%9C%EB%82%9819+%EC%98%88%EB%B0%A9%EC%88%98%EC%B9%99&DA=NPI
# https://search.daum.net/search?w=tot&q=%EB%85%B8%ED%99%8D%EC%B2%A0+%EA%B8%B0%EB%B6%80&DA=NPI&rtmaxcoll=NNS
# https://search.daum.net/search?w=tot&q=%ED%99%94%ED%99%98&DA=NPT
# https://search.daum.net/search?w=tot&q=%ED%99%A9%ED%9D%AC%EC%B0%AC+4%EC%A3%BC%EA%B2%B0%EC%9E%A5&DA=NPI&rtmaxcoll=NNS
# https://search.daum.net/search?w=tot&q=%EB%B0%B0%EB%84%88&DA=NPT
# https://news.daum.net/covid19
# /doc/startpage.html
# http://cafe.daum.net/
# https://mail.daum.net/
# http://media.daum.net/
# https://map.kakao.com/
# http://finance.daum.net/
# https://shoppinghow.kakao.com/top
# http://tv.kakao.com
# http://webtoon.daum.net/
# http://blog.daum.net/
# https://brunch.co.kr
# http://dic.daum.net/
# http://game.daum.net
# https://together.kakao.com
# javascript:;
# https://mail.daum.net
# http://cafe.daum.net
# http://blog.daum.net
# http://www.tistory.com
# https://brunch.co.kr
# https://agit.io/
# https://story.kakao.com/s/login
# http://media.daum.net/?nil_profile=mini&nil_src=news
# http://sports.media.daum.net
# http://media.daum.net/entertain
# https://lazzy.kakao.com/
# https://shoppinghow.kakao.com/top
# https://flights.kakao.com/
# http://finance.daum.net
# https://realty.daum.net/?nil_profile=mini&nil_src=realestate
# http://auto.daum.net
# https://www.melon.com/index.htm?ref=W10204
# http://movie.daum.net
# http://webtoon.daum.net
# http://tv.kakao.com/top
# https://together.kakao.com
# https://makers.kakao.com/
# https://project100.kakao.com/
# https://dic.daum.net
# http://translate.kakao.com
# http://wordbook.daum.net
# http://100.daum.net
# http://tip.daum.net
# http://game.daum.net/
# https://pubg.game.daum.net/
# https://pathofexile.game.daum.net
# https://map.kakao.com/
# https://map.kakao.com/index.jsp?target=car
# http://map.kakao.com/?panoid=1024043871&pan=327.5&tilt=-4.5&zoom=0&map_type=TYPE_SKYVIEW&map_hybrid=true&map_attribute=ROADVIEW&urlX=494966&urlY=1132203&urlLevel=4
# http://map.kakao.com/index.jsp?target=traffic&opt=2&nil_profile=g
# http://map.kakao.com/index.jsp?REGION=01&STARTNAME=&ENDNAME=&OPTION=1&URLLINK=true&target=subway
# https://www.kakaocorp.com/
# https://kakao.ai/
# sitemap/index.html
# javascript:void(0);
# //search.daum.net/search?w=tot&q=날씨&DA=TMN
# //search.daum.net/search?w=tot&q=미세먼지&DA=TMO
# //search.daum.net/search?w=tot&q=통합대기&DA=TMO
# https://logins.daum.net/accounts/dsso.do?url=https%3A%2F%2Fwww.daum.net%2F
# https://logins.daum.net/accounts/ksso.do?url=https%3A%2F%2Fwww.daum.net%2F
# https://accounts.kakao.com/weblogin/create_account?continue=https%3A%2F%2Fwww.daum.net
# http://media.daum.net/
# https://v.daum.net/v/20200307090129959
# https://auto.v.daum.net/v/20200307091804156
# https://v.daum.net/v/20200307120302419
# https://v.daum.net/v/20200307121339550
# https://v.daum.net/v/20200307124244801
# https://v.daum.net/v/20200307110253554
# https://v.daum.net/v/20200307142456740
# https://v.daum.net/v/20200307142452739
# https://v.daum.net/v/20200307142335729
# https://v.daum.net/v/20200307142002702
# https://v.daum.net/v/20200307140948577
# https://v.daum.net/v/20200307141334627
# https://v.daum.net/v/20200307125506889
# https://v.daum.net/v/20200307140424526
# https://v.daum.net/v/20200307135811440
# https://v.daum.net/v/20200307124410816
# https://v.daum.net/v/20200307133858257
# https://v.daum.net/v/20200307132451116
# https://v.daum.net/v/20200307131927076
# https://v.daum.net/v/20200307131435036
# https://v.daum.net/v/20200307130211963
# http://media.daum.net/
# http://media.daum.net/issue/
# http://media.daum.net/series/
# http://media.daum.net/ranking/popular/
# http://media.daum.net/tv/
# http://media.daum.net/photo/
# https://search.daum.net/search?w=tot&q=%EC%A6%9D%EC%8B%9C&DA=TMZ
# https://search.daum.net/search?w=tot&q=%ED%99%98%EC%9C%A8&DA=TMZ
# https://search.daum.net/search?w=tot&q=%EC%9A%B4%EC%84%B8&DA=TMZ
# https://search.daum.net/search?w=tot&q=%ED%8E%B8%EC%84%B1%ED%91%9C&DA=TMZ
# https://media.daum.net/issue/5008621
# http://media.daum.net/entertain
# http://sports.media.daum.net/sports
# http://movie.daum.net
# http://auto.daum.net/index.daum
# https://realty.daum.net
# http://tv.kakao.com/top
# #none
# #none
# #none
# #none
# https://media.daum.net/entertain/tv/1329423/video/407052519
# https://media.daum.net/entertain/tv/5000788/video/407049691
# https://media.daum.net/entertain/tv/119149/video/407052628
# https://media.daum.net/entertain/tv/1681936/video/407051911
# https://tv.kakao.com/channel/3443320/cliplink/405741228
# https://tv.kakao.com/channel/3273005/cliplink/406467113
# https://tv.kakao.com/channel/2654116/cliplink/406925655
# https://tv.kakao.com/channel/3460510/cliplink/406884657
# https://newslink.media.daum.net/v/407056100
# https://newslink.media.daum.net/v/407061281
# https://newslink.media.daum.net/v/407055646
# https://newslink.media.daum.net/v/407055540
# https://tv.kakao.com/v/405409078
# https://tv.kakao.com/v/406613385
# https://tv.kakao.com/v/406686839
# https://tv.kakao.com/v/406676197
# http://top.cafe.daum.net/
# https://brunch.co.kr/
# https://brunch.co.kr/brunchbook/drink-alcohol
# https://brunch.co.kr/brunchbook/hastysentiment
# https://brunch.co.kr/brunchbook/illillteacher1
# https://brunch.co.kr/brunchbook/kk32167
# http://www.tistory.com/
# https://1boon.daum.net/
# https://story.kakao.com/
# #none
# #none
# https://1boon.daum.net/docs/5e5e1c1310b5763b694b6a38
# https://1boon.daum.net/docs/5e62981fdc055229a8aef178
# https://1boon.daum.net/docs/5e61f378dc055229a8aee9f0
# https://brunch.co.kr/@@2ub/591
# https://v.daum.net/v/20200306210609575
# https://1boon.daum.net/docs/5e30ded2bc6d9b20e0b9f3ff
# https://1boon.daum.net/docs/5e61b595cca99512707d0d77
# https://v.daum.net/v/20200304112120868
# https://1boon.daum.net/docs/5e54b9c81a20fc5534960745
# https://v.daum.net/v/20200304140510535
# https://v.daum.net/v/20200304121947867
# https://v.daum.net/v/20200304095215922
# https://1boon.daum.net/docs/5e5e466110b5763b694b6c48
# https://v.daum.net/v/20200304051006831
# #none
# #none
# #none
# #none
# #none
# http://www.melon.com/
# http://webtoon.daum.net
# http://game.daum.net/
# https://together.kakao.com
# http://ammonia.daum.net/cptclick?contentseq=1607161&puid=84415247755156789&pagenum=1&impprodnum=0&contentnum=1&positionseq=17485&detailpositionseq=17484
# http://media.daum.net/photo/
# #prevPhoto
# #nextPhoto
# <url>https://gallery.v.daum.net/p/premium/fishing3/jLHYai8jGY</url>
# <url>https://gallery.v.daum.net/p/premium/ESQUIREKOREA/jORy0TYSvG</url>
# <url>https://gallery.v.daum.net/p/premium/realbasketball/jLxNCv4ZDK</url>
# <url>https://gallery.v.daum.net/p/viewer/250/20200307105641459</url>
# <url>https://gallery.v.daum.net/p/viewer/5014013/20200307142935790</url>
# <url>https://gallery.v.daum.net/p/viewer/5013055/20200307124028786</url>
# <url>https://gallery.v.daum.net/p/viewer/252/20200307105046377</url>
# <url>https://gallery.v.daum.net/p/viewer/247/20200307085116819</url>
# <url>https://gallery.v.daum.net/p/viewer/1489/20200307060119198</url>
# <url>https://gallery.v.daum.net/p/viewer/987/20200306164332579</url>
# <url>https://gallery.v.daum.net/p/viewer/48212/20200307060057179</url>
# <url>https://gallery.v.daum.net/p/viewer/5021176/20200306061004722</url>
# <url>https://gallery.v.daum.net/p/viewer/3027/20200307080420381</url>
# <url>https://gallery.v.daum.net/p/viewer/318190/20200306190419034</url>
# <url>https://gallery.v.daum.net/p/viewer/3600/20200307060305291</url>
# <url>https://gallery.v.daum.net/p/viewer/182938/20200307090608036</url>
# #prevPhotoList
# #nextPhotoList
# https://www.daum.net/
# http://m.daum.net/channel/new/notice
# https://m.daum.net/channel/new/notice/view/5e5f5785a7b54302ff0bf80f?title=Daum+%EB%A9%94%EC%9D%BC+%EC%A3%BC%EC%86%8C%EB%A1%9D+%EC%84%9C%EB%B9%84%EC%8A%A4+%EC%A0%90%EA%B2%80%283%EC%9B%94+6%EC%9D%BC%29+%EC%95%88%EB%82%B4&date=2020-03-04
# sitemap/index.html
# https://www.kakaocorp.com
# https://business.kakao.com
# https://register.search.daum.net/index.daum
# http://with.kakao.com/
# https://careers.kakao.com/index
# http://policy.daum.net/info/info
# http://policy.daum.net/operation_policy/operation_policy
# http://policy.daum.net/youthpolicy/youthpolicy
# http://policy.daum.net/info_protection/info_protection
# https://www.daum.net/doc/top_accessibility.html
# https://cs.daum.net/
# http://www.kakaocorp.com/
