# %%
# conda create n 이름 python=3.6
# conda install n d_study c conda forge autopep8 pylint jupyter_contrib_nbextensions
    # Nbextensions 설치
#jupyter notebook

# %%
conda env list
# Out:
# # conda environments:
# #
# base                  *  C:\Users\User\anaconda3
# stat                     C:\Users\User\anaconda3\envs\stat
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda activate stat

# %%
conda list
# Out:
# # packages in environment at C:\Users\User\anaconda3:
# #
# # Name                    Version                   Build  Channel
# _anaconda_depends         2020.02                  py37_0
# _ipyw_jlab_nb_ext_conf    0.1.0                    py37_0
# absl-py                   0.9.0                    pypi_0    pypi
# alabaster                 0.7.12                   py37_0
# anaconda                  custom                   py37_1
# anaconda-client           1.7.2                    py37_0
# anaconda-navigator        1.9.12                   py37_0
# anaconda-project          0.8.4                      py_0
# argh                      0.26.2                   py37_0
# asn1crypto                1.3.0                    py37_0
# astroid                   2.4.0                    py37_0
# astropy                   4.0.1.post1      py37he774522_0
# astunparse                1.6.3                    pypi_0    pypi
# atomicwrites              1.4.0                      py_0
# ...
